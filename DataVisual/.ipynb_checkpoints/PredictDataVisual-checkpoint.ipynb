# %% [markdown]
# ## Plot longitude and latitude

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
from mpl_toolkits.basemap import Basemap

# %%
true_latitude = pd.read_csv("../Result/true_latitude.csv")
true_longitude = pd.read_csv("../Result/true_longitude.csv")
# data from Yi Qin
predict_latitude = pd.read_csv("../Result/predict_latitude.csv")
predict_longitude = pd.read_csv("../Result/predict_longitude.csv")
# data from Ge Qu
predict_latitude_q = pd.read_csv("../Result/latitude_result.csv")
predict_longitude_q = pd.read_csv("../Result/longitude_result.csv")

# %%
plt.figure(figsize=(20,10))
m1 = Basemap(projection='merc',
             llcrnrlat=-60,
             urcrnrlat=65,
             llcrnrlon=-180,
             urcrnrlon=180,
             lat_ts=0,
             resolution='c')


m1.fillcontinents(color='#191919',lake_color='#000000') # dark grey land, black lakes
m1.drawmapboundary(fill_color='#000000')                # black background
m1.drawcountries(linewidth=0.1, color="w")              # thin white line for country borders

# Plot the data
# x,y true
x,y = m1(true_longitude['True_longitude'].tolist(),true_latitude['True_latitude'].tolist())
# x_1, y_1 from Yi Qin
x_1, y_1 = m1(predict_longitude['true longitude'].tolist(),predict_latitude['Predict_latitude'].tolist())
# x_2, y_2 from Ge Qu
x_2,y_2 = m1(predict_longitude_q['0'].tolist(),predict_latitude_q['0'].tolist())
m1.scatter(x_2,y_2, s=3, c="#1292db", lw=0, alpha=1, zorder=5)
m1.scatter(x,y, s=3, c='r', lw=0,alpha=1,zorder=5)
plt.title("Pokemon activity")
plt.show()

# %% [markdown]
# ## Plot city

# %%
true = pd.read_csv("../Result/city.csv")
true.head()
# len(true)
predict = pd.read_csv("../Result/Predict_city.csv")
predict.head()
# len(predict)
# Out:
#    Unnamed: 0       0
# 0           0   Tokyo
# 1           1    Rome
# 2           2  Manila
# 3           3  Prague
# 4           4  Madrid

# %%
true = pd.read_csv("../Result/city_label.csv")
predict = pd.read_csv("../Result/city_pred.csv")
print(len(true))
# Out:
# 88807

# %%
cnt = true.groupby('0')['0'].size()
cnt_p = predict.groupby('0')['0'].size()
# cnt['label']='0'
# print(cnt)
# print(cnt_p.head())

# %%
# cnt = cnt.to_frame()
cnt_index = np.expand_dims(np.array(cnt.index),axis=1)
cnt_values = np.expand_dims(np.array(cnt.values),axis=1)
print ("cnt_index:len{}\n{}".format(len(cnt_index),cnt_index))
print ("cnt_values:len()\n{}".format(len(cnt_index),cnt_values))
label = np.full((len(cnt_index),1),'true')
cnt_true = np.concatenate((cnt_index,cnt_values,label),axis=1)
# cnt = np.array(cnt)
# cnt.reindex(columns={cnt.columns[1]:'value'},inplace=True)
print(cnt_true)
# Out:
# cnt_index:len89
# [['Adelaide']
#  ['Amman']
#  ['Amsterdam']
#  ['Athens']
#  ['Auckland']
#  ['Bahia']
#  ['Bangkok']
#  ['Belem']
#  ['Berlin']
#  ['Boise']
#  ['Bratislava']
#  ['Brisbane']
#  ['Brunei']
#  ['Brussels']
#  ['Bucharest']
#  ['Buenos_Aires']
#  ['Casablanca']
#  ['Chicago']
#  ['Copenhagen']
#  ['Cordoba']
#  ['Costa_Rica']
#  ['Denver']
#  ['Detroit']
#  ['Dubai']
#  ['Dublin']
#  ['Edmonton']
#  ['Guam']
#  ['Guayaquil']
#  ['Halifax']
#  ['Helsinki']
#  ['Ho_Chi_Minh']
#  ['Hobart']
#  ['Hong_Kong']
#  ['Honolulu']
#  ['Indianapolis']
#  ['Isle_of_Man']
#  ['Istanbul']
#  ['Jakarta']
#  ['Karachi']
#  ['Kiev']
#  ['Kolkata']
#  ['Kuala_Lumpur']
#  ['Kuching']
#  ['Lisbon']
#  ['Ljubljana']
#  ['London']
#  ['Los_Angeles']
#  ['Louisville']
#  ['Luanda']
#  ['Luxembourg']
#  ['Madrid']
#  ['Manila']
#  ['Melbourne']
#  ['Mexico_City']
#  ['Monterrey']
#  ['Montreal']
#  ['Moscow']
#  ['Nairobi']
#  ['New_York']
#  ['Nicosia']
#  ['Noumea']
#  ['Oslo']
#  ['Paris']
#  ['Perth']
#  ['Phoenix']
#  ['Prague']
#  ['Puerto_Rico']
#  ['Regina']
#  ['Reunion']
#  ['Reykjavik']
#  ['Rome']
#  ['Santiago']
#  ['Sao_Paulo']
#  ['Sarajevo']
#  ['Singapore']
#  ['Stockholm']
#  ['Sydney']
#  ['Taipei']
#  ['Tokyo']
#  ['Toronto']
#  ['Tripoli']
#  ['Tunis']
#  ['Vancouver']
#  ['Vienna']
#  ['Vilnius']
#  ['Warsaw']
#  ['Winnipeg']
#  ['Zagreb']
#  ['Zurich']]
# cnt_values:len()
# 89
# [['Adelaide' 3 'true']
#  ['Amman' 2 'true']
#  ['Amsterdam' 633 'true']
#  ['Athens' 44 'true']
#  ['Auckland' 517 'true']
#  ['Bahia' 11 'true']
#  ['Bangkok' 806 'true']
#  ['Belem' 40 'true']
#  ['Berlin' 454 'true']
#  ['Boise' 32 'true']
#  ['Bratislava' 29 'true']
#  ['Brisbane' 45 'true']
#  ['Brunei' 510 'true']
#  ['Brussels' 17 'true']
#  ['Bucharest' 439 'true']
#  ['Buenos_Aires' 276 'true']
#  ['Casablanca' 2 'true']
#  ['Chicago' 9591 'true']
#  ['Copenhagen' 178 'true']
#  ['Cordoba' 11 'true']
#  ['Costa_Rica' 1 'true']
#  ['Denver' 1730 'true']
#  ['Detroit' 162 'true']
#  ['Dubai' 48 'true']
#  ['Dublin' 803 'true']
#  ['Edmonton' 1797 'true']
#  ['Guam' 18 'true']
#  ['Guayaquil' 25 'true']
#  ['Halifax' 26 'true']
#  ['Helsinki' 8 'true']
#  ['Ho_Chi_Minh' 198 'true']
#  ['Hobart' 47 'true']
#  ['Hong_Kong' 406 'true']
#  ['Honolulu' 32 'true']
#  ['Indianapolis' 332 'true']
#  ['Isle_of_Man' 7 'true']
#  ['Istanbul' 8 'true']
#  ['Jakarta' 62 'true']
#  ['Karachi' 4 'true']
#  ['Kiev' 10 'true']
#  ['Kolkata' 111 'true']
#  ['Kuala_Lumpur' 145 'true']
#  ['Kuching' 621 'true']
#  ['Lisbon' 13 'true']
#  ['Ljubljana' 1618 'true']
#  ['London' 5790 'true']
#  ['Los_Angeles' 6495 'true']
#  ['Louisville' 2 'true']
#  ['Luanda' 12 'true']
#  ['Luxembourg' 16 'true']
#  ['Madrid' 1333 'true']
#  ['Manila' 349 'true']
#  ['Melbourne' 679 'true']
#  ['Mexico_City' 3781 'true']
#  ['Monterrey' 280 'true']
#  ['Montreal' 86 'true']
#  ['Moscow' 4 'true']
#  ['Nairobi' 1 'true']
#  ['New_York' 16348 'true']
#  ['Nicosia' 17 'true']
#  ['Noumea' 12 'true']
#  ['Oslo' 1785 'true']
#  ['Paris' 3395 'true']
#  ['Perth' 72 'true']
#  ['Phoenix' 1643 'true']
#  ['Prague' 8471 'true']
#  ['Puerto_Rico' 174 'true']
#  ['Regina' 208 'true']
#  ['Reunion' 1 'true']
#  ['Reykjavik' 10 'true']
#  ['Rome' 4730 'true']
#  ['Santiago' 37 'true']
#  ['Sao_Paulo' 343 'true']
#  ['Sarajevo' 1 'true']
#  ['Singapore' 404 'true']
#  ['Stockholm' 2949 'true']
#  ['Sydney' 202 'true']
#  ['Taipei' 71 'true']
#  ['Tokyo' 882 'true']
#  ['Toronto' 1088 'true']
#  ['Tripoli' 6 'true']
#  ['Tunis' 10 'true']
#  ['Vancouver' 979 'true']
#  ['Vienna' 630 'true']
#  ['Vilnius' 67 'true']
#  ['Warsaw' 1283 'true']
#  ['Winnipeg' 227 'true']
#  ['Zagreb' 71 'true']
#  ['Zurich' 1991 'true']]

# %%
# cnt = cnt.to_frame()
cnt_p_index = np.expand_dims(np.array(cnt.index),axis=1)
cnt_p_values = np.expand_dims(np.array(cnt.values),axis=1)
print ("cnt_index:len{}\n{}".format(len(cnt_index),cnt_index))
print ("cnt_values:len()\n{}".format(len(cnt_index),cnt_values))
label_p = np.full((len(cnt_index),1),'predict')
cnt_predict = np.concatenate((cnt_p_index,cnt_p_values,label_p),axis=1)
# cnt = np.array(cnt)
# cnt.reindex(columns={cnt.columns[1]:'value'},inplace=True)
print(cnt_predict)
# Out:
# cnt_index:len89
# [['Adelaide']
#  ['Amman']
#  ['Amsterdam']
#  ['Athens']
#  ['Auckland']
#  ['Bahia']
#  ['Bangkok']
#  ['Belem']
#  ['Berlin']
#  ['Boise']
#  ['Bratislava']
#  ['Brisbane']
#  ['Brunei']
#  ['Brussels']
#  ['Bucharest']
#  ['Buenos_Aires']
#  ['Casablanca']
#  ['Chicago']
#  ['Copenhagen']
#  ['Cordoba']
#  ['Costa_Rica']
#  ['Denver']
#  ['Detroit']
#  ['Dubai']
#  ['Dublin']
#  ['Edmonton']
#  ['Guam']
#  ['Guayaquil']
#  ['Halifax']
#  ['Helsinki']
#  ['Ho_Chi_Minh']
#  ['Hobart']
#  ['Hong_Kong']
#  ['Honolulu']
#  ['Indianapolis']
#  ['Isle_of_Man']
#  ['Istanbul']
#  ['Jakarta']
#  ['Karachi']
#  ['Kiev']
#  ['Kolkata']
#  ['Kuala_Lumpur']
#  ['Kuching']
#  ['Lisbon']
#  ['Ljubljana']
#  ['London']
#  ['Los_Angeles']
#  ['Louisville']
#  ['Luanda']
#  ['Luxembourg']
#  ['Madrid']
#  ['Manila']
#  ['Melbourne']
#  ['Mexico_City']
#  ['Monterrey']
#  ['Montreal']
#  ['Moscow']
#  ['Nairobi']
#  ['New_York']
#  ['Nicosia']
#  ['Noumea']
#  ['Oslo']
#  ['Paris']
#  ['Perth']
#  ['Phoenix']
#  ['Prague']
#  ['Puerto_Rico']
#  ['Regina']
#  ['Reunion']
#  ['Reykjavik']
#  ['Rome']
#  ['Santiago']
#  ['Sao_Paulo']
#  ['Sarajevo']
#  ['Singapore']
#  ['Stockholm']
#  ['Sydney']
#  ['Taipei']
#  ['Tokyo']
#  ['Toronto']
#  ['Tripoli']
#  ['Tunis']
#  ['Vancouver']
#  ['Vienna']
#  ['Vilnius']
#  ['Warsaw']
#  ['Winnipeg']
#  ['Zagreb']
#  ['Zurich']]
# cnt_values:len()
# 89
# [['Adelaide' 3 'predict']
#  ['Amman' 2 'predict']
#  ['Amsterdam' 633 'predict']
#  ['Athens' 44 'predict']
#  ['Auckland' 517 'predict']
#  ['Bahia' 11 'predict']
#  ['Bangkok' 806 'predict']
#  ['Belem' 40 'predict']
#  ['Berlin' 454 'predict']
#  ['Boise' 32 'predict']
#  ['Bratislava' 29 'predict']
#  ['Brisbane' 45 'predict']
#  ['Brunei' 510 'predict']
#  ['Brussels' 17 'predict']
#  ['Bucharest' 439 'predict']
#  ['Buenos_Aires' 276 'predict']
#  ['Casablanca' 2 'predict']
#  ['Chicago' 9591 'predict']
#  ['Copenhagen' 178 'predict']
#  ['Cordoba' 11 'predict']
#  ['Costa_Rica' 1 'predict']
#  ['Denver' 1730 'predict']
#  ['Detroit' 162 'predict']
#  ['Dubai' 48 'predict']
#  ['Dublin' 803 'predict']
#  ['Edmonton' 1797 'predict']
#  ['Guam' 18 'predict']
#  ['Guayaquil' 25 'predict']
#  ['Halifax' 26 'predict']
#  ['Helsinki' 8 'predict']
#  ['Ho_Chi_Minh' 198 'predict']
#  ['Hobart' 47 'predict']
#  ['Hong_Kong' 406 'predict']
#  ['Honolulu' 32 'predict']
#  ['Indianapolis' 332 'predict']
#  ['Isle_of_Man' 7 'predict']
#  ['Istanbul' 8 'predict']
#  ['Jakarta' 62 'predict']
#  ['Karachi' 4 'predict']
#  ['Kiev' 10 'predict']
#  ['Kolkata' 111 'predict']
#  ['Kuala_Lumpur' 145 'predict']
#  ['Kuching' 621 'predict']
#  ['Lisbon' 13 'predict']
#  ['Ljubljana' 1618 'predict']
#  ['London' 5790 'predict']
#  ['Los_Angeles' 6495 'predict']
#  ['Louisville' 2 'predict']
#  ['Luanda' 12 'predict']
#  ['Luxembourg' 16 'predict']
#  ['Madrid' 1333 'predict']
#  ['Manila' 349 'predict']
#  ['Melbourne' 679 'predict']
#  ['Mexico_City' 3781 'predict']
#  ['Monterrey' 280 'predict']
#  ['Montreal' 86 'predict']
#  ['Moscow' 4 'predict']
#  ['Nairobi' 1 'predict']
#  ['New_York' 16348 'predict']
#  ['Nicosia' 17 'predict']
#  ['Noumea' 12 'predict']
#  ['Oslo' 1785 'predict']
#  ['Paris' 3395 'predict']
#  ['Perth' 72 'predict']
#  ['Phoenix' 1643 'predict']
#  ['Prague' 8471 'predict']
#  ['Puerto_Rico' 174 'predict']
#  ['Regina' 208 'predict']
#  ['Reunion' 1 'predict']
#  ['Reykjavik' 10 'predict']
#  ['Rome' 4730 'predict']
#  ['Santiago' 37 'predict']
#  ['Sao_Paulo' 343 'predict']
#  ['Sarajevo' 1 'predict']
#  ['Singapore' 404 'predict']
#  ['Stockholm' 2949 'predict']
#  ['Sydney' 202 'predict']
#  ['Taipei' 71 'predict']
#  ['Tokyo' 882 'predict']
#  ['Toronto' 1088 'predict']
#  ['Tripoli' 6 'predict']
#  ['Tunis' 10 'predict']
#  ['Vancouver' 979 'predict']
#  ['Vienna' 630 'predict']
#  ['Vilnius' 67 'predict']
#  ['Warsaw' 1283 'predict']
#  ['Winnipeg' 227 'predict']
#  ['Zagreb' 71 'predict']
#  ['Zurich' 1991 'predict']]

# %%
cnt_all = np.concatenate((cnt_true,cnt_predict),axis=0)
cnt_all_df = pd.DataFrame(cnt_all,columns=['city','values','label'])
cnt_all_df[['values']]= cnt_all_df[['values']].apply(pd.to_numeric)
cnt_all_df
# print(type(cnt_all_df['values']))
# Out:
#              city  values    label
# 0        Adelaide       3     true
# 1           Amman       2     true
# 2       Amsterdam     633     true
# 3          Athens      44     true
# 4        Auckland     517     true
# 5           Bahia      11     true
# 6         Bangkok     806     true
# 7           Belem      40     true
# 8          Berlin     454     true
# 9           Boise      32     true
# 10     Bratislava      29     true
# 11       Brisbane      45     true
# 12         Brunei     510     true
# 13       Brussels      17     true
# 14      Bucharest     439     true
# 15   Buenos_Aires     276     true
# 16     Casablanca       2     true
# 17        Chicago    9591     true
# 18     Copenhagen     178     true
# 19        Cordoba      11     true
# 20     Costa_Rica       1     true
# 21         Denver    1730     true
# 22        Detroit     162     true
# 23          Dubai      48     true
# 24         Dublin     803     true
# 25       Edmonton    1797     true
# 26           Guam      18     true
# 27      Guayaquil      25     true
# 28        Halifax      26     true
# 29       Helsinki       8     true
# ..            ...     ...      ...
# 148       Nicosia      17  predict
# 149        Noumea      12  predict
# 150          Oslo    1785  predict
# 151         Paris    3395  predict
# 152         Perth      72  predict
# 153       Phoenix    1643  predict
# 154        Prague    8471  predict
# 155   Puerto_Rico     174  predict
# 156        Regina     208  predict
# 157       Reunion       1  predict
# 158     Reykjavik      10  predict
# 159          Rome    4730  predict
# 160      Santiago      37  predict
# 161     Sao_Paulo     343  predict
# 162      Sarajevo       1  predict
# 163     Singapore     404  predict
# 164     Stockholm    2949  predict
# 165        Sydney     202  predict
# 166        Taipei      71  predict
# 167         Tokyo     882  predict
# 168       Toronto    1088  predict
# 169       Tripoli       6  predict
# 170         Tunis      10  predict
# 171     Vancouver     979  predict
# 172        Vienna     630  predict
# 173       Vilnius      67  predict
# 174        Warsaw    1283  predict
# 175      Winnipeg     227  predict
# 176        Zagreb      71  predict
# 177        Zurich    1991  predict
#
# [178 rows x 3 columns]

# %%
# data = (
#     cnt_all_df.set_index('city')
#       .stack()  # un-pivots the data 
#       .reset_index()  # moves all data out of the index
#       .rename(columns={'level_1': 'Variable', 0: 'Value'})
# )

# %%
f, ax = plt.subplots(figsize=(20, 10))
sns.barplot(x=cnt_all_df['city'], y=cnt_all_df['values'], hue=cnt_all_df['label'], data=cnt_all_df, ax=ax)
plt.xticks(rotation=90)
plt.setp(ax.patches, linewidth=0)
texts = ax.set(title="Count activity by City")

# %% [markdown]
# ## Plot Pokemon

# %%
Names = pd.read_csv("../Data/pokemonNumbers.csv",header=None)
Names.columns = ['pokemonid', 'name']
Names['pokemonid'] = Names['pokemonid'].apply(lambda x: x-1)
Names.head()
dictionary = dict(zip(Names['pokemonid'], Names['name']))
