# %% [markdown]
# ## Plot longitude and latitude

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.basemap import Basemap

# %%
true_latitude = pd.read_csv("../Result/true_latitude.csv")
true_longitude = pd.read_csv("../Result/true_longitude.csv")
# data from Yi Qin
predict_latitude = pd.read_csv("../Result/predict_latitude.csv")
predict_longitude = pd.read_csv("../Result/predict_longitude.csv")
# data from Ge Qu
predict_latitude_q = pd.read_csv("../Result/latitude_result.csv")
predict_longitude_q = pd.read_csv("../Result/longitude_result.csv")

# %%
plt.figure(figsize=(20,10))
m1 = Basemap(projection='merc',
             llcrnrlat=-60,
             urcrnrlat=65,
             llcrnrlon=-180,
             urcrnrlon=180,
             lat_ts=0,
             resolution='c')


m1.fillcontinents(color='#191919',lake_color='#000000') # dark grey land, black lakes
m1.drawmapboundary(fill_color='#000000')                # black background
m1.drawcountries(linewidth=0.1, color="w")              # thin white line for country borders

# Plot the data
# x,y true
x,y = m1(true_longitude['True_longitude'].tolist(),true_latitude['True_latitude'].tolist())
# x_1, y_1 from Yi Qin
x_1, y_1 = m1(predict_longitude['true longitude'].tolist(),predict_latitude['Predict_latitude'].tolist())
# x_2, y_2 from Ge Qu
x_2,y_2 = m1(predict_longitude_q['0'].tolist(),predict_latitude_q['0'].tolist())
m1.scatter(x_2,y_2, s=3, c="#1292db", lw=0, alpha=1, zorder=5)
m1.scatter(x,y, s=3, c='r', lw=0,alpha=1,zorder=5)
plt.title("Pokemon activity")
plt.show()

# %% [markdown]
# ## Plot city

# %%
true = pd.read_csv("../Result/city.csv")
true.head()
# len(true)
predict = pd.read_csv("../Result/Predict_city.csv")
predict.head()
# len(predict)
# Out:
#    Unnamed: 0       0
# 0           0   Tokyo
# 1           1    Rome
# 2           2  Manila
# 3           3  Prague
# 4           4  Madrid

# %%
cnt = true.groupby('0')['0'].size()
cnt_p = predict.groupby('0')['0'].size()
# cnt['label']='0'
# print(cnt)
# print(cnt_p.head())

# %%
# cnt = cnt.to_frame()
cnt_index = np.expand_dims(np.array(cnt.index),axis=1)
cnt_values = np.expand_dims(np.array(cnt.values),axis=1)
print ("cnt_index:len{}\n{}".format(len(cnt_index),cnt_index))
print ("cnt_values:len()\n{}".format(len(cnt_index),cnt_values))
label = np.full((len(cnt_index),1),'true')
cnt_true = np.concatenate((cnt_index,cnt_values,label),axis=1)
# cnt = np.array(cnt)
# cnt.reindex(columns={cnt.columns[1]:'value'},inplace=True)
print(cnt_true)
# Out:
# cnt_index:len89
# [['Adelaide']
#  ['Amsterdam']
#  ['Athens']
#  ['Auckland']
#  ['Bahia']
#  ['Bangkok']
#  ['Belem']
#  ['Berlin']
#  ['Boise']
#  ['Bratislava']
#  ['Brisbane']
#  ['Brunei']
#  ['Brussels']
#  ['Bucharest']
#  ['Buenos_Aires']
#  ['Cairo']
#  ['Casablanca']
#  ['Chicago']
#  ['Copenhagen']
#  ['Cordoba']
#  ['Costa_Rica']
#  ['Denver']
#  ['Detroit']
#  ['Dubai']
#  ['Dublin']
#  ['Edmonton']
#  ['Guam']
#  ['Guayaquil']
#  ['Guyana']
#  ['Halifax']
#  ['Helsinki']
#  ['Ho_Chi_Minh']
#  ['Hobart']
#  ['Hong_Kong']
#  ['Honolulu']
#  ['Indianapolis']
#  ['Isle_of_Man']
#  ['Istanbul']
#  ['Jakarta']
#  ['Karachi']
#  ['Kiev']
#  ['Kolkata']
#  ['Kuala_Lumpur']
#  ['Kuching']
#  ['Lisbon']
#  ['Ljubljana']
#  ['London']
#  ['Los_Angeles']
#  ['Louisville']
#  ['Luanda']
#  ['Luxembourg']
#  ['Madrid']
#  ['Manila']
#  ['Melbourne']
#  ['Mexico_City']
#  ['Monterrey']
#  ['Montreal']
#  ['Moscow']
#  ['New_York']
#  ['Nicosia']
#  ['Noumea']
#  ['Oslo']
#  ['Paris']
#  ['Perth']
#  ['Phoenix']
#  ['Prague']
#  ['Puerto_Rico']
#  ['Regina']
#  ['Reunion']
#  ['Reykjavik']
#  ['Rome']
#  ['Santiago']
#  ['Sao_Paulo']
#  ['Sarajevo']
#  ['Singapore']
#  ['Stockholm']
#  ['Sydney']
#  ['Taipei']
#  ['Tokyo']
#  ['Toronto']
#  ['Tripoli']
#  ['Tunis']
#  ['Vancouver']
#  ['Vienna']
#  ['Vilnius']
#  ['Warsaw']
#  ['Winnipeg']
#  ['Zagreb']
#  ['Zurich']]
# cnt_values:len()
# 89
# [['Adelaide' 1 'true']
#  ['Amsterdam' 635 'true']
#  ['Athens' 36 'true']
#  ['Auckland' 562 'true']
#  ['Bahia' 17 'true']
#  ['Bangkok' 832 'true']
#  ['Belem' 27 'true']
#  ['Berlin' 462 'true']
#  ['Boise' 30 'true']
#  ['Bratislava' 32 'true']
#  ['Brisbane' 48 'true']
#  ['Brunei' 528 'true']
#  ['Brussels' 14 'true']
#  ['Bucharest' 416 'true']
#  ['Buenos_Aires' 332 'true']
#  ['Cairo' 1 'true']
#  ['Casablanca' 2 'true']
#  ['Chicago' 9573 'true']
#  ['Copenhagen' 177 'true']
#  ['Cordoba' 3 'true']
#  ['Costa_Rica' 3 'true']
#  ['Denver' 1655 'true']
#  ['Detroit' 122 'true']
#  ['Dubai' 65 'true']
#  ['Dublin' 763 'true']
#  ['Edmonton' 1785 'true']
#  ['Guam' 18 'true']
#  ['Guayaquil' 19 'true']
#  ['Guyana' 2 'true']
#  ['Halifax' 36 'true']
#  ['Helsinki' 20 'true']
#  ['Ho_Chi_Minh' 233 'true']
#  ['Hobart' 51 'true']
#  ['Hong_Kong' 361 'true']
#  ['Honolulu' 30 'true']
#  ['Indianapolis' 298 'true']
#  ['Isle_of_Man' 8 'true']
#  ['Istanbul' 5 'true']
#  ['Jakarta' 59 'true']
#  ['Karachi' 7 'true']
#  ['Kiev' 10 'true']
#  ['Kolkata' 88 'true']
#  ['Kuala_Lumpur' 134 'true']
#  ['Kuching' 645 'true']
#  ['Lisbon' 11 'true']
#  ['Ljubljana' 1620 'true']
#  ['London' 5806 'true']
#  ['Los_Angeles' 6802 'true']
#  ['Louisville' 5 'true']
#  ['Luanda' 15 'true']
#  ['Luxembourg' 13 'true']
#  ['Madrid' 1464 'true']
#  ['Manila' 335 'true']
#  ['Melbourne' 651 'true']
#  ['Mexico_City' 3891 'true']
#  ['Monterrey' 292 'true']
#  ['Montreal' 91 'true']
#  ['Moscow' 6 'true']
#  ['New_York' 15977 'true']
#  ['Nicosia' 18 'true']
#  ['Noumea' 10 'true']
#  ['Oslo' 1786 'true']
#  ['Paris' 3407 'true']
#  ['Perth' 95 'true']
#  ['Phoenix' 1699 'true']
#  ['Prague' 8409 'true']
#  ['Puerto_Rico' 199 'true']
#  ['Regina' 219 'true']
#  ['Reunion' 1 'true']
#  ['Reykjavik' 9 'true']
#  ['Rome' 4723 'true']
#  ['Santiago' 30 'true']
#  ['Sao_Paulo' 333 'true']
#  ['Sarajevo' 1 'true']
#  ['Singapore' 434 'true']
#  ['Stockholm' 2874 'true']
#  ['Sydney' 196 'true']
#  ['Taipei' 56 'true']
#  ['Tokyo' 854 'true']
#  ['Toronto' 1061 'true']
#  ['Tripoli' 5 'true']
#  ['Tunis' 8 'true']
#  ['Vancouver' 995 'true']
#  ['Vienna' 587 'true']
#  ['Vilnius' 68 'true']
#  ['Warsaw' 1317 'true']
#  ['Winnipeg' 233 'true']
#  ['Zagreb' 66 'true']
#  ['Zurich' 1990 'true']]

# %%
# cnt = cnt.to_frame()
cnt_p_index = np.expand_dims(np.array(cnt.index),axis=1)
cnt_p_values = np.expand_dims(np.array(cnt.values),axis=1)
print ("cnt_index:len{}\n{}".format(len(cnt_index),cnt_index))
print ("cnt_values:len()\n{}".format(len(cnt_index),cnt_values))
label_p = np.full((len(cnt_index),1),'predict')
cnt_predict = np.concatenate((cnt_p_index,cnt_p_values,label_p),axis=1)
# cnt = np.array(cnt)
# cnt.reindex(columns={cnt.columns[1]:'value'},inplace=True)
print(cnt_predict)
# Out:
# cnt_index:len89
# [['Adelaide']
#  ['Amsterdam']
#  ['Athens']
#  ['Auckland']
#  ['Bahia']
#  ['Bangkok']
#  ['Belem']
#  ['Berlin']
#  ['Boise']
#  ['Bratislava']
#  ['Brisbane']
#  ['Brunei']
#  ['Brussels']
#  ['Bucharest']
#  ['Buenos_Aires']
#  ['Cairo']
#  ['Casablanca']
#  ['Chicago']
#  ['Copenhagen']
#  ['Cordoba']
#  ['Costa_Rica']
#  ['Denver']
#  ['Detroit']
#  ['Dubai']
#  ['Dublin']
#  ['Edmonton']
#  ['Guam']
#  ['Guayaquil']
#  ['Guyana']
#  ['Halifax']
#  ['Helsinki']
#  ['Ho_Chi_Minh']
#  ['Hobart']
#  ['Hong_Kong']
#  ['Honolulu']
#  ['Indianapolis']
#  ['Isle_of_Man']
#  ['Istanbul']
#  ['Jakarta']
#  ['Karachi']
#  ['Kiev']
#  ['Kolkata']
#  ['Kuala_Lumpur']
#  ['Kuching']
#  ['Lisbon']
#  ['Ljubljana']
#  ['London']
#  ['Los_Angeles']
#  ['Louisville']
#  ['Luanda']
#  ['Luxembourg']
#  ['Madrid']
#  ['Manila']
#  ['Melbourne']
#  ['Mexico_City']
#  ['Monterrey']
#  ['Montreal']
#  ['Moscow']
#  ['New_York']
#  ['Nicosia']
#  ['Noumea']
#  ['Oslo']
#  ['Paris']
#  ['Perth']
#  ['Phoenix']
#  ['Prague']
#  ['Puerto_Rico']
#  ['Regina']
#  ['Reunion']
#  ['Reykjavik']
#  ['Rome']
#  ['Santiago']
#  ['Sao_Paulo']
#  ['Sarajevo']
#  ['Singapore']
#  ['Stockholm']
#  ['Sydney']
#  ['Taipei']
#  ['Tokyo']
#  ['Toronto']
#  ['Tripoli']
#  ['Tunis']
#  ['Vancouver']
#  ['Vienna']
#  ['Vilnius']
#  ['Warsaw']
#  ['Winnipeg']
#  ['Zagreb']
#  ['Zurich']]
# cnt_values:len()
# 89
# [['Adelaide' 1 'predict']
#  ['Amsterdam' 635 'predict']
#  ['Athens' 36 'predict']
#  ['Auckland' 562 'predict']
#  ['Bahia' 17 'predict']
#  ['Bangkok' 832 'predict']
#  ['Belem' 27 'predict']
#  ['Berlin' 462 'predict']
#  ['Boise' 30 'predict']
#  ['Bratislava' 32 'predict']
#  ['Brisbane' 48 'predict']
#  ['Brunei' 528 'predict']
#  ['Brussels' 14 'predict']
#  ['Bucharest' 416 'predict']
#  ['Buenos_Aires' 332 'predict']
#  ['Cairo' 1 'predict']
#  ['Casablanca' 2 'predict']
#  ['Chicago' 9573 'predict']
#  ['Copenhagen' 177 'predict']
#  ['Cordoba' 3 'predict']
#  ['Costa_Rica' 3 'predict']
#  ['Denver' 1655 'predict']
#  ['Detroit' 122 'predict']
#  ['Dubai' 65 'predict']
#  ['Dublin' 763 'predict']
#  ['Edmonton' 1785 'predict']
#  ['Guam' 18 'predict']
#  ['Guayaquil' 19 'predict']
#  ['Guyana' 2 'predict']
#  ['Halifax' 36 'predict']
#  ['Helsinki' 20 'predict']
#  ['Ho_Chi_Minh' 233 'predict']
#  ['Hobart' 51 'predict']
#  ['Hong_Kong' 361 'predict']
#  ['Honolulu' 30 'predict']
#  ['Indianapolis' 298 'predict']
#  ['Isle_of_Man' 8 'predict']
#  ['Istanbul' 5 'predict']
#  ['Jakarta' 59 'predict']
#  ['Karachi' 7 'predict']
#  ['Kiev' 10 'predict']
#  ['Kolkata' 88 'predict']
#  ['Kuala_Lumpur' 134 'predict']
#  ['Kuching' 645 'predict']
#  ['Lisbon' 11 'predict']
#  ['Ljubljana' 1620 'predict']
#  ['London' 5806 'predict']
#  ['Los_Angeles' 6802 'predict']
#  ['Louisville' 5 'predict']
#  ['Luanda' 15 'predict']
#  ['Luxembourg' 13 'predict']
#  ['Madrid' 1464 'predict']
#  ['Manila' 335 'predict']
#  ['Melbourne' 651 'predict']
#  ['Mexico_City' 3891 'predict']
#  ['Monterrey' 292 'predict']
#  ['Montreal' 91 'predict']
#  ['Moscow' 6 'predict']
#  ['New_York' 15977 'predict']
#  ['Nicosia' 18 'predict']
#  ['Noumea' 10 'predict']
#  ['Oslo' 1786 'predict']
#  ['Paris' 3407 'predict']
#  ['Perth' 95 'predict']
#  ['Phoenix' 1699 'predict']
#  ['Prague' 8409 'predict']
#  ['Puerto_Rico' 199 'predict']
#  ['Regina' 219 'predict']
#  ['Reunion' 1 'predict']
#  ['Reykjavik' 9 'predict']
#  ['Rome' 4723 'predict']
#  ['Santiago' 30 'predict']
#  ['Sao_Paulo' 333 'predict']
#  ['Sarajevo' 1 'predict']
#  ['Singapore' 434 'predict']
#  ['Stockholm' 2874 'predict']
#  ['Sydney' 196 'predict']
#  ['Taipei' 56 'predict']
#  ['Tokyo' 854 'predict']
#  ['Toronto' 1061 'predict']
#  ['Tripoli' 5 'predict']
#  ['Tunis' 8 'predict']
#  ['Vancouver' 995 'predict']
#  ['Vienna' 587 'predict']
#  ['Vilnius' 68 'predict']
#  ['Warsaw' 1317 'predict']
#  ['Winnipeg' 233 'predict']
#  ['Zagreb' 66 'predict']
#  ['Zurich' 1990 'predict']]

# %%
cnt_all = np.concatenate((cnt_true,cnt_predict),axis=0)
cnt_all_df = pd.DataFrame(cnt_all,columns=['city','values','label'])
cnt_all_df[['values']]= cnt_all_df[['values']].apply(pd.to_numeric)
cnt_all_df
# print(type(cnt_all_df['values']))
# Out:
#              city  values    label
# 0        Adelaide       1     true
# 1       Amsterdam     635     true
# 2          Athens      36     true
# 3        Auckland     562     true
# 4           Bahia      17     true
# 5         Bangkok     832     true
# 6           Belem      27     true
# 7          Berlin     462     true
# 8           Boise      30     true
# 9      Bratislava      32     true
# 10       Brisbane      48     true
# 11         Brunei     528     true
# 12       Brussels      14     true
# 13      Bucharest     416     true
# 14   Buenos_Aires     332     true
# 15          Cairo       1     true
# 16     Casablanca       2     true
# 17        Chicago    9573     true
# 18     Copenhagen     177     true
# 19        Cordoba       3     true
# 20     Costa_Rica       3     true
# 21         Denver    1655     true
# 22        Detroit     122     true
# 23          Dubai      65     true
# 24         Dublin     763     true
# 25       Edmonton    1785     true
# 26           Guam      18     true
# 27      Guayaquil      19     true
# 28         Guyana       2     true
# 29        Halifax      36     true
# ..            ...     ...      ...
# 148       Nicosia      18  predict
# 149        Noumea      10  predict
# 150          Oslo    1786  predict
# 151         Paris    3407  predict
# 152         Perth      95  predict
# 153       Phoenix    1699  predict
# 154        Prague    8409  predict
# 155   Puerto_Rico     199  predict
# 156        Regina     219  predict
# 157       Reunion       1  predict
# 158     Reykjavik       9  predict
# 159          Rome    4723  predict
# 160      Santiago      30  predict
# 161     Sao_Paulo     333  predict
# 162      Sarajevo       1  predict
# 163     Singapore     434  predict
# 164     Stockholm    2874  predict
# 165        Sydney     196  predict
# 166        Taipei      56  predict
# 167         Tokyo     854  predict
# 168       Toronto    1061  predict
# 169       Tripoli       5  predict
# 170         Tunis       8  predict
# 171     Vancouver     995  predict
# 172        Vienna     587  predict
# 173       Vilnius      68  predict
# 174        Warsaw    1317  predict
# 175      Winnipeg     233  predict
# 176        Zagreb      66  predict
# 177        Zurich    1990  predict
#
# [178 rows x 3 columns]

# %%
# data = (
#     cnt_all_df.set_index('city')
#       .stack()  # un-pivots the data 
#       .reset_index()  # moves all data out of the index
#       .rename(columns={'level_1': 'Variable', 0: 'Value'})
# )

# %%
f, ax = plt.subplots(figsize=(20, 10))
sns.barplot(x=cnt_all_df['city'], y=cnt_all_df['values'], hue=cnt_all_df['label'], data=cnt_all_df, ax=ax)
plt.xticks(rotation=90)
plt.setp(ax.patches, linewidth=0)
texts = ax.set(title="Count activity by City")
